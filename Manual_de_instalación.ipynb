# %% [markdown]
# # Manual de instalación
# ## Requisitos previos
# ## Tener instalado Python 3.8 o superior.
#
# ## Tener instalado Jupyter Notebook o acceder a Google Colab.
#
# ## Conexión a Internet estable.
#
# ## Acceso a las API o recursos necesarios (por ejemplo, acceso a Gemini que en nuestro caso lo usaremos para tener una conección a una IA).
#
# ## En caso de usar librerías externas, haber instalado dependencias con:
# ## pip install -r requirements.txt
# ## Descarga del proyecto
# ## Clona o descarga este repositorio desde GitHub:
#
# ##git clone https://github.com/Carlos19711101/arbelaes_presiga_velez_ea3/blob/main/notebook_limpio.ipynb
#
# ## Ejecución en Google Colab
#
# ## Abre el archivo EA3_IA_GENERATIVA_GEMINI.ipynb que en nuestro caso se le cambio el nombre en el repositorio porque se tubo que limpiar los metadatos su nombre actual es, notebook_limpio.ipynb dentro de Google Colab.
#
# ## Ejecuta las celdas secuencialmente para reproducir la generación visual y textual.
#
# ## Configure cualquier parámetro o llave en las celdas indicadas.
#
# # Ejecución local
# ## Si prefieres ejecutar localmente, abre el  notebook_limpio.ipynb en tu pc y ejecutalo.
#
# ## Asegúrese de instalar las dependencias necesarias.
#
# ## Ejecuta las celdas del notebook para reproducir la generación y experimentación.
